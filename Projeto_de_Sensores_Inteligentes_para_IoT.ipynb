# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovitorcg04/detector-falhas-pcb-yolov8/blob/main/Projeto_de_Sensores_Inteligentes_para_IoT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 84.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 111.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="D2alzK3EZmCXpeQfco8E")
project = rf.workspace("joo-ncb0r").project("pcb-holes-mg34h")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 41.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 73.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to PCB-Holes-1 in yolov8:: 100%|██████████| 492/492 [00:00<00:00, 6259.76it/s]
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(data=f'{dataset.location}/data.yaml', epochs=100, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 200MB/s]
# Ultralytics 8.3.165 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
import cv2

# 1. Carrega o SEU modelo treinado que acabamos de criar.
# Certifique-se de que o caminho para o arquivo 'best.pt' está correto!
model = YOLO('runs/detect/train/weights/best.pt')  # <-- ATENÇÃO AQUI!

# 2. Coloque o nome do arquivo da imagem que você acabou de subir.
# Lembre-se de colocar o nome exato, incluindo a extensão (.jpg, .png, etc.).
image_path = '/content/Types of PCB Holes.jpg'


# 3. Roda a detecção na sua nova imagem
results = model(image_path)

# 4. Salva o resultado em um novo arquivo e o exibe na tela
output_filename = 'resultado_final.jpg'
results[0].save(filename=output_filename)

print(f"Resultado salvo como '{output_filename}'!")
img = cv2.imread(output_filename)
cv2_imshow(img)
# Out:
# image 1/1 /content/Types of PCB Holes.jpg: 448x640 4 missing holes, 36.5ms
# Speed: 2.9ms preprocess, 36.5ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Resultado salvo como 'resultado_final.jpg'!
# <PIL.Image.Image image mode=RGB size=617x409>
